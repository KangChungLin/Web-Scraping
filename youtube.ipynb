# %%
# 匯入套件


# 操作 browser 的 API
from selenium import webdriver

# 處理逾時例外的工具
from selenium.common.exceptions import TimeoutException

# 面對動態網頁，等待某個元素出現的工具，通常與 exptected_conditions 搭配
from selenium.webdriver.support.ui import WebDriverWait

# 搭配 WebDriverWait 使用，對元素狀態的一種期待條件，若條件發生，則等待結束，往下一行執行
from selenium.webdriver.support import expected_conditions as EC

# 期待元素出現要透過什麼方式指定，通常與 EC、WebDriverWait 一起使用
from selenium.webdriver.common.by import By

# 強制等待 (執行期間休息一下)
from time import sleep

# 整理 json 使用的工具
import json

# 執行 command 的時候用的
import os

# 使用 Chrome 的 WebDriver
driver = webdriver.Chrome()

# 螢幕最大化
#driver.maximize_window()

# 放置爬取的資料
listData = []


# 以 function 名稱，作為爬蟲流程


# 走訪頁面
def visit():
    driver.get('https://www.youtube.com/');

# 輸入關鍵字
def search():
    # 輸入名稱
    txtInput = driver.find_element(By.CSS_SELECTOR, "input#search")
    txtInput.send_keys("周興哲")
    
    #按下送出
    btnInput = driver.find_element(By.CSS_SELECTOR, "button#search-icon-legacy")
    btnInput.click()

def filterFunc():
    # 等待篩選元素出現
    # 等10秒
    WebDriverWait(driver, 10).until(
        EC.presence_of_element_located( 
            (By.CSS_SELECTOR, "yt-formatted-string#text.style-scope.ytd-toggle-button-renderer.style-text")   # 一個id兩個class
        )
    )
    
    #按下篩選元素，使項目浮現
    driver.find_element(By.CSS_SELECTOR, "yt-formatted-string#text.style-scope.ytd-toggle-button-renderer.style-text").click()
    
    # 等待一下
    sleep(2)
    
    # 按下選擇的項目
    driver.find_elements(By.CSS_SELECTOR, "yt-formatted-string.style-scope.ytd-search-filter-renderer")[10].click()

# 滾動頁面
def scroll():
    # 瀏覽器內部的高度
    innerHeightOfWindow = 0
    
    # 當前捲動的量(高度)
    totalOffset = 0
    
    # 在捲動到沒有元素動態產生前，持續捲動
    while totalOffset <= innerHeightOfWindow:
        # 每次移動高度
        totalOffset += 300;
        
        # 捲動的 js code
        # 為了避免format & function的{}搞混，function需要{{}}
        js_scroll = '''(
            function (){{
                window.scrollTo({{
                    top:{}, 
                    behavior: 'smooth' 
                }});
            }})();'''.format(totalOffset)
        
        # 執行 js code
        driver.execute_script(js_scroll)
        
        # 強制等待
        sleep(1)
        
        # 透過執行 js 語法來取得捲動後的當前總高度
        innerHeightOfWindow = driver.execute_script('return window.document.documentElement.scrollHeight;');
        
        # 強制等待
        sleep(1)
        
        # 印出捲動距離
        print("innerHeightOfWindow: {}, totalOffset: {}".format(innerHeightOfWindow, totalOffset))
        
        # 為了實驗功能，捲動超過一定的距離，就結束程式
        if totalOffset >= 300:
            break

# 分析頁面元素資訊
def parse():
    # 取得主要元素的集合
    ytd_video_renderers = driver.find_elements(By.CSS_SELECTOR, 'ytd-video-renderer.style-scope.ytd-item-section-renderer')
    
    # 逐一檢視元素
    for element in ytd_video_renderers:
        # 取得圖片連結
        img = element.find_element(By.CSS_SELECTOR, "ytd-thumbnail.style-scope.ytd-video-renderer img#img")
        imgSrc = img.get_attribute('src')
        print(imgSrc)
        
        # 取得資料名稱
        a = element.find_element(By.CSS_SELECTOR, "a#video-title")
        aTitle = a.text
        print(aTitle)
        
        aLink = a.get_attribute('href')
        print(aLink)
        
        # 放資料到 list 中
        listData.append({
            "imgSrc": imgSrc,
            "aTitle": aTitle,
            "aLink": aLink
        })

# 將 list 存成 json
def saveJson():
    fp = open("youtube.json", "w", encoding='utf-8')
    fp.write( json.dumps(listData, ensure_ascii=False) )
    fp.close()
    
# 關閉瀏覽器
def close():
    driver.quit()


# 主程式
visit()
search()
filterFunc()
scroll()
parse()
saveJson()
close()

# %%
'''
匯入套件
'''
# 操作 browser 的 API
from selenium import webdriver

# 處理逾時例外的工具
from selenium.common.exceptions import TimeoutException

# 面對動態網頁，等待某個元素出現的工具，通常與 exptected_conditions 搭配
from selenium.webdriver.support.ui import WebDriverWait

# 搭配 WebDriverWait 使用，對元素狀態的一種期待條件，若條件發生，則等待結束，往下一行執行
from selenium.webdriver.support import expected_conditions as EC

# 期待元素出現要透過什麼方式指定，通常與 EC、WebDriverWait 一起使用
from selenium.webdriver.common.by import By

# 強制等待 (執行期間休息一下)
from time import sleep

# 整理 json 使用的工具
import json

# 執行 command 的時候用的
import os

# 使用 Chrome 的 WebDriver
driver = webdriver.Chrome()

# 螢幕最大化
#driver.maximize_window()

# 放置爬取的資料
listData = []

'''
以 function 名稱，作為爬蟲流程
'''

# 走訪頁面
def visit():
    driver.get('https://www.youtube.com/');

# 輸入關鍵字
def search():
    # 輸入名稱
    txtInput = driver.find_element(By.CSS_SELECTOR, "input#search")
    txtInput.send_keys("張學友")
    
    #按下送出
    btnInput = driver.find_element(By.CSS_SELECTOR, "button#search-icon-legacy")
    btnInput.click()
    
# 篩選 (選項)
def filterFunc():
    # 等待篩選元素出現
    WebDriverWait(driver, 10).until(
        EC.presence_of_element_located( 
            (By.CSS_SELECTOR, "yt-formatted-string#text.style-scope.ytd-toggle-button-renderer.style-text") 
        )
    )
    
    #按下篩選元素，使項目浮現
    driver.find_element(By.CSS_SELECTOR, "yt-formatted-string#text.style-scope.ytd-toggle-button-renderer.style-text").click()
    
    # 等待一下
    sleep(2)
    
    # 按下選擇的項目
    driver.find_elements(By.CSS_SELECTOR, "yt-formatted-string.style-scope.ytd-search-filter-renderer")[10].click()

# 滾動頁面
def scroll():
    # 瀏覽器內部的高度
    innerHeightOfWindow = 0
    
    # 當前捲動的量(高度)
    totalOffset = 0
    
    # 在捲動到沒有元素動態產生前，持續捲動
    while totalOffset <= innerHeightOfWindow:
        # 每次移動高度
        totalOffset += 300;
        
        # 捲動的 js code
        js_scroll = '''(
            function (){{
                window.scrollTo({{
                    top:{}, 
                    behavior: 'smooth' 
                }});
            }})();'''.format(totalOffset)
        
        # 執行 js code
        driver.execute_script(js_scroll)
        
        # 強制等待
        sleep(1)
        
        # 透過執行 js 語法來取得捲動後的當前總高度
        innerHeightOfWindow = driver.execute_script('return window.document.documentElement.scrollHeight;');
        
        # 強制等待
        sleep(1)
        
        # 印出捲動距離
        print("innerHeightOfWindow: {}, totalOffset: {}".format(innerHeightOfWindow, totalOffset))
        
        # 為了實驗功能，捲動超過一定的距離，就結束程式
        if totalOffset >= 300:
            break

# 分析頁面元素資訊
def parse():
    # 取得主要元素的集合
    ytd_video_renderers = driver.find_elements(By.CSS_SELECTOR, 'ytd-video-renderer.style-scope.ytd-item-section-renderer')
    
    # 逐一檢視元素
    for element in ytd_video_renderers:
        # 取得圖片連結
        img = element.find_element(By.CSS_SELECTOR, "ytd-thumbnail.style-scope.ytd-video-renderer img#img")
        imgSrc = img.get_attribute('src')
        print(imgSrc)
        
        # 取得資料名稱
        a = element.find_element(By.CSS_SELECTOR, "a#video-title")
        aTitle = a.text
        print(aTitle)
        
        aLink = a.get_attribute('href')
        print(aLink)
        
        # 放資料到 list 中
        listData.append({
            "imgSrc": imgSrc,
            "aTitle": aTitle,
            "aLink": aLink
        })

# 將 list 存成 json
def saveJson():
    fp = open("youtube.json", "w", encoding='utf-8')
    fp.write( json.dumps(listData, ensure_ascii=False) )
    fp.close()
    
# 關閉瀏覽器
def close():
    driver.quit()

# ??????
def download():
    # 開啟 json 檔案
    fp = open("youtube.json", "r", encoding='utf-8')
    
    #取得 json 字串
    strJson = fp.read()
    
    # 關閉檔案
    fp.close()
    
    # 將 json 轉成 list (裡面是 dict 集合)
    listResult = json.loads(strJson)
    
    # ??????
    for index, obj in enumerate(listResult):
        if index <= 2:
            os.system("youtube-dl.exe -f mp4 -i {} -o {}".format(obj["aLink"], "%(id)s.%(ext)s"))
    


# 主程式
visit()
search()
filterFunc()
scroll()
parse()
saveJson()
close()
download()
# Out:
# innerHeightOfWindow: 3542, totalOffset: 300
# https://i.ytimg.com/vi/O9JBVray8Ic/hqdefault.jpg?sqp=-oaymwEZCPYBEIoBSFXyq4qpAwsIARUAAIhCGAFwAQ==&rs=AOn4CLBQDfVmJrPbv1j-TlTaN7ey2A6ZhQ
# 張學友 Jacky Cheung –《等風雨經過》MV
# https://www.youtube.com/watch?v=O9JBVray8Ic
# https://i.ytimg.com/vi/V_aEvo6JorU/hqdefault.jpg?sqp=-oaymwEZCPYBEIoBSFXyq4qpAwsIARUAAIhCGAFwAQ==&rs=AOn4CLApKTw3WFDjAFwHkEKD1vyu0QoubQ
# 張學友-1997演(2005如果愛版)
# https://www.youtube.com/watch?v=V_aEvo6JorU
# https://i.ytimg.com/vi/E5KQen8bOiY/hqdefault.jpg?sqp=-oaymwEZCPYBEIoBSFXyq4qpAwsIARUAAIhCGAFwAQ==&rs=AOn4CLAxBR6VjB2XVEMK5r7b7UpHscaUHQ
# 张学友 - 我真的受伤了 [歌词]
# https://www.youtube.com/watch?v=E5KQen8bOiY
# https://i.ytimg.com/vi/_7GjLNtbOlk/hqdefault.jpg?sqp=-oaymwEZCPYBEIoBSFXyq4qpAwsIARUAAIhCGAFwAQ==&rs=AOn4CLCM-PKC_9OQZHqUDVs-mpZcb3ofJA
# Jacky Cheung 張學友 [時間有淚/Tears Of Time]Official 官方 MV
# https://www.youtube.com/watch?v=_7GjLNtbOlk
# https://i.ytimg.com/vi/wCToQQvW30w/hqdefault.jpg?sqp=-oaymwEZCPYBEIoBSFXyq4qpAwsIARUAAIhCGAFwAQ==&rs=AOn4CLDH8qMF4y7CwQQ0dIcLakd2VKe6kA
# 張學友表白神曲《我愛你》，電影東成西就經典片段
# https://www.youtube.com/watch?v=wCToQQvW30w
# https://i.ytimg.com/vi/Z0nM2jjqtiU/hqdefault.jpg?sqp=-oaymwEZCPYBEIoBSFXyq4qpAwsIARUAAIhCGAFwAQ==&rs=AOn4CLASzYEE-uXWGdCuVdRgswHln_mzeg
# 20190105中天新聞　張學友哪首歌最難唱！？　本人唱到搖頭險破音
# https://www.youtube.com/watch?v=Z0nM2jjqtiU
# https://i.ytimg.com/vi/csUGvkUXu3Y/hqdefault.jpg?sqp=-oaymwEZCPYBEIoBSFXyq4qpAwsIARUAAIhCGAFwAQ==&rs=AOn4CLCx-oaKLkbmqo2LXtUZqd3eriWi4Q
# 賺到了!張學友高雄終場彩蛋 清唱江蕙"家後"│中視新聞20190107
# https://www.youtube.com/watch?v=csUGvkUXu3Y
# https://i.ytimg.com/vi/-s6aAqfx0dk/hqdefault.jpg?sqp=-oaymwEZCPYBEIoBSFXyq4qpAwsIARUAAIhCGAFwAQ==&rs=AOn4CLC9h5zgOVe5e5QRin3VoQrHCXKLfQ
# 張學友 Jacky Cheung - 萬水千山縱橫
# https://www.youtube.com/watch?v=-s6aAqfx0dk
# None
# 20190104中天新聞　演唱會門票秒殺！「歌神」張學友唱出真誠
# https://www.youtube.com/watch?v=DjpS4KmHN_o
# None
# 張學友~忘情泠兩夜(國語版~故事)
# https://www.youtube.com/watch?v=qXXdkOlxBRU
# None
# 張學友《我願意》王菲《情書》`97 天王天后互唱對方經典歌曲
# https://www.youtube.com/watch?v=zTyrHmoF1vo
# None
# 20190330中天新聞　超給面子！　柯有倫婚禮張學友大咖們席地而坐
# https://www.youtube.com/watch?v=xkCHJUXvpB4
# None
# 張學友~分手總要在雨天~金獎
# https://www.youtube.com/watch?v=DShg65WKMJo
# None
# 張學友 ( 我真的受傷了 ) 經典世界巡迴演唱會香港站 2019年1月 Jacky Cheung
# https://www.youtube.com/watch?v=SSA31lnNE7U
# None
# 20180124中天新聞　演唱會門票秒殺！「歌神」張學友唱出真誠
# https://www.youtube.com/watch?v=WvGfG76fIt0
# None
# 張學友 (Jacky Cheung) -「天黑黑」(HD)
# https://www.youtube.com/watch?v=CYrGXSngscg
# None
# 张学友 - 浪子心聲 [From the Heart of a Loafer]
# https://www.youtube.com/watch?v=mxzQrpTrhRk
# None
# 張學友-CORAZON DE MELAO(演唱會)-英語.mpg
# https://www.youtube.com/watch?v=sJqCcWBuYbw
# None
# 张学友 - 天下无双 (原唱：陈奕迅) (动态歌词)
# https://www.youtube.com/watch?v=r7h98udXVrQ
# None
# 妳是愛我的 / You Do Love Me - 張學友 / Jacky Cheung
# https://www.youtube.com/watch?v=T8w4WiYLeAQ
